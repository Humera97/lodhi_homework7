# %% [markdown]
# # Cherry Blossoms!
#
# If we travel back in time a few months, [cherry blossoms](https://en.wikipedia.org/wiki/Cherry_blossom) were in full bloom! We don't live in Japan or DC, but we do have our fair share of the trees - buuut you sadly missed [Brooklyn Botanic Garden's annual festival](https://www.bbg.org/visit/event/sakura_matsuri_2019).
#
# We'll have to make up for it with data-driven cherry blossoms instead. Once upon a time [Data is Plural](https://tinyletter.com/data-is-plural) linked to [a dataset](http://atmenv.envi.osakafu-u.ac.jp/aono/kyophenotemp4/) about when the cherry trees blossom each year. It's a little out of date, but it's quirky in a real nice way so we're sticking with it.
#
# ## 0. Do all of your importing/setup stuff

# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.read_excel('KyotoFullFlower7.xls')

# %% [markdown]
# ## 1. Read in the file using pandas, and look at the first five rows

# %%
df.head(5)
# Out:
#   Full-flowering dates of Japanese cherry (Prunus jamasakura) at Kyoto, Japan. (Latest version, Jun. 12, 2012)  \
# 0  This phenological data was acquired by followi...
# 1                                                NaN
# 2                                     Column A; A.D.
# 3       Column B; Full-flowering date (day of year).
# 4  Column C; Full-flowering date (calender date, ...
#
#   Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN

# %% [markdown]
# ## 2. Read in the file using pandas CORRECTLY, and look at the first five rows
#
# Hrm, how do your column names look? Read the file in again but this time add a parameter to make sure your columns look right.
#
# **TIP: The first year should be 801 AD, and it should not have any dates or anything.**

# %%
df = pd.read_excel('KyotoFullFlower7.xls',skiprows = 25)
df.head(5)
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN              -
# 1             NaN              -
# 2             NaN              -
# 3             NaN              -
# 4             NaN              -

# %% [markdown]
# ## 3. Look at the final five rows of the data

# %%
df.tail(5)
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#       Data type code          Reference Name
# 1210             0.0  NEWS-PAPER(ARASHIYAMA)
# 1211             0.0  NEWS-PAPER(ARASHIYAMA)
# 1212             0.0  NEWS-PAPER(ARASHIYAMA)
# 1213             0.0  NEWS-PAPER(ARASHIYAMA)
# 1214             0.0  NEWS-PAPER(ARASHIYAMA)

# %% [markdown]
# ## 4. Add some more NaN values

# %% [markdown]
# It looks like you should probably have some NaN/missing values earlier on in the dataset under "Reference name." Read in the file *one more time*, this time making sure all of those missing reference names actually show up as `NaN` instead of `-`.

# %%
df = pd.read_excel('KyotoFullFlower7.xls',skiprows = 25,na_values ='-')

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name
# 0             NaN            NaN
# 1             NaN            NaN
# 2             NaN            NaN
# 3             NaN            NaN
# 4             NaN            NaN

# %%
df['ReferenceName'] = df['Reference Name']

# %% [markdown]
# ## 4. What source is the most common as a reference?

# %%
df.ReferenceName.value_counts()
# Out:
# NEWS-PAPER(ARASHIYAMA)                     94
# SUGIURAKE-NIKKI                            38
# MYOHOIN-HINAMIKI                           32
# OYUDONONO-UENO-NIKKI                       26
# OYUDONONO-UENO-NIKKI [EDA]                 21
# DAIGOJI-ZATSUYO                            21
# NIHONKIRYAKU                               19
# SANETAKA-KOKI                              19
# (SHIRYO-SORAN)                             15
# KAKUMEIKI                                  15
# ZOKU-SHIGUSHO                              14
# NISUIKI                                    13
# INRYOGEN-NICHIROKU                         13
# MEIGETSUKI                                 12
# GIENJUNKO-NIKKI(DAIGO)                     10
# GUKANKI                                    10
# MOTOHIRO-KOKI                               9
# KANMON-GYOKI(FUSHIMI)                       9
# DAIGO-ZOJIKI                                9
# KEIHAN RAILWAY ADV(ARASHIYAMA)              9
# TOKIYOSHI-KYOKI                             8
# TAKAGI-ZAICHU-NIKKI                         8
# ZOKU-HONCHOTSUKAN                           8
# HANAZONOTENNO-SHINKI                        8
# MANZAIJUNGO-NIKKI(DAIGO)                    8
# TERUYOSHI-KOKI                              8
# RAI-SANYO-NIPPU                             8
# TOKITSUGU-KYOKI                             8
# (DAINIHON-SHIRYO)                           7
# CHUYUKI                                     6
#                                            ..
# IETSUNE-ASON-SHU                            1
# MIAKE-SHONOSUKE-NIKKI                       1
# EISHOKI                                     1
# EST-from-WF(HONCHO-SEIKI)                   1
# EITOKU-GANNEN-GYOKO-SHIIKA                  1
# NORITOKI-KYOKI                              1
# ZOKU-KOKIN-WAKASHU                          1
# RYOGEN-IN-KI                                1
# EST-from-WF(ZOKU-SHIGUSHO)                  1
# TAKAKURAIN-ANGEN-ONGAKI                     1
# MOROZANE-SHU                                1
# SHINGISHIKI                                 1
# HARU-NO-NISHIKI                             1
# OZAKITADAMASA-NIKKI                         1
# YATAKA-SHU                                  1
# GYOJO-HOSSINNO-NIKKI [KINDAI]               1
# MITSUTSUNE-SHU                              1
# NAKASUKEOKI                                 1
# REKIDAI-HENNEN-SHUSEI                       1
# MISININ-KAMPAKUKI                           1
# EST-from-KJ(KUJOKE-REKISEI-KIROKU)          1
# HEKIZAN-NICHIROKU                           1
# NOBUTANE-KYOKI                              1
# KYOHAKUSHU                                  1
# HARETOYOKI                                  1
# MISSHU-KETSUMYAKUSHO                        1
# GYOJO-HOSSINNO-NIKKI [KIYOMIZU-CHIONIN]     1
# SADAMOTO-KYOKI                              1
# SHIKIN-WAKASO                               1
# GYOJO-HOSSINNO-NIKKI [SEIRYODEN]            1
# Name: ReferenceName, Length: 222, dtype: int64

# %% [markdown]
# ## 6. Filter the list to only include columns where the `Full-flowering date (DOY)` is not missing
#
# If you'd like to do it in two steps (which might be easier to think through), first figure out how to test whether a column is empty/missing/null/NaN, get the list of `True`/`False` values, and then later feed it to your `df`.

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#    Data type code Reference Name ReferenceName
# 0             NaN            NaN           NaN
# 1             NaN            NaN           NaN
# 2             NaN            NaN           NaN
# 3             NaN            NaN           NaN
# 4             NaN            NaN           NaN

# %%
#df_flowering = df['Full-flowering date (DOY)'].dropna()
#df_flowering
#df['Full-flowering date (DOY)'].dropna()
df_flowering = df[df['Full-flowering date (DOY)'].notnull()]
df_flowering.head()
#df[df['Full-flowering date (DOY)']]
# Out:
#      AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 11  812                       92.0                401.0          1.0
# 14  815                      105.0                415.0          1.0
# 30  831                       96.0                406.0          1.0
# 50  851                      108.0                418.0          1.0
# 52  853                      104.0                414.0          1.0
#
#     Data type code          Reference Name           ReferenceName
# 11             2.0              NIHON-KOKI              NIHON-KOKI
# 14             2.0              NIHON-KOKI              NIHON-KOKI
# 30             2.0              NIHON-KOKI              NIHON-KOKI
# 50             2.0  MONTOKUTENNO-JITSUROKU  MONTOKUTENNO-JITSUROKU
# 52             2.0  MONTOKUTENNO-JITSUROKU  MONTOKUTENNO-JITSUROKU

# %% [markdown]
# ## 7. Make a histogram of the full-flowering date
#
# Is it not showing up? Remember the "magic" command that makes graphs show up in matplotlib notebooks!

# %%
df_flowering['Full-flowering date (DOY)'].hist()

# %% [markdown]
# ## 8. Make another histogram of the full-flowering date, but with 39 bins instead of 10

# %%
df_flowering['Full-flowering date (DOY)'].hist(bins=39)

# %% [markdown]
# ## 9. What's the average number of days it takes for the flowers to blossom? And how many records do we have?
#
# Answer these both with one line of code.

# %%
df_flowering['Full-flowering date (DOY)'].describe()
# Out:
# count    827.000000
# mean     104.540508
# std        6.407036
# min       86.000000
# 25%      100.000000
# 50%      105.000000
# 75%      109.000000
# max      124.000000
# Name: Full-flowering date (DOY), dtype: float64

# %% [markdown]
# #### Number of Records: 827
# #### Average Number of Days it takes flowers to bloom: 104.54

# %% [markdown]
# ## 10. What's the average days into the year cherry flowers normally blossomed before 1900?

# %%
df_flowering[df.AD < 1900]['Full-flowering date (DOY)'].mean()
# Out:
# /Users/humeralodhi/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 105.20728291316527

# %% [markdown]
# ## 11. How about after 1900?

# %%
df_flowering[df.AD > 1900]['Full-flowering date (DOY)'].mean()
# Out:
# /Users/humeralodhi/.pyenv/versions/3.7.1/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# 100.3125

# %% [markdown]
# ## 12. How many times was our data from a title in Japanese poetry?
#
# You'll need to read the documentation inside of the Excel file.

# %%
df['Data type code'] = df['Data type code'].replace({
    0: 'data from modern times (full-bloom date since 1880s)',
    1: 'from diary description about full-bloom',
    2: 'from diary description about cherry blossom viewing party',
    3: 'from diary description about presents of cherry twigs from party participants',
    4: 'A title in Japanese poetry',
    8: 'Deduced from wisteria phenology, using the relation proposed by Aono and Saito (2010)',
    9: 'Deduced from Japanese kerria phenology, using the relation proposed by Aono (2011)'

})

# %%
df =df.rename(columns={
    'Data type code': 'Data_type_code'
})
df[df.Data_type_code == 'A title in Japanese poetry'].count()
# Out:
# AD                           39
# Full-flowering date (DOY)    39
# Full-flowering date          39
# Source code                  39
# Data_type_code               39
# Reference Name               39
# ReferenceName                39
# dtype: int64

# %% [markdown]
# ## 13. Show only the years where our data was from a title in Japanese poetry

# %%
df[df.Data_type_code == 'A title in Japanese poetry'].AD
# Out:
# 90       891
# 94       895
# 95       896
# 122      923
# 154      955
# 168      969
# 206     1007
# 232     1033
# 235     1036
# 259     1060
# 260     1061
# 283     1084
# 294     1095
# 381     1182
# 389     1190
# 400     1201
# 415     1216
# 418     1219
# 420     1221
# 422     1223
# 435     1236
# 464     1265
# 467     1268
# 468     1269
# 470     1271
# 488     1289
# 500     1301
# 523     1324
# 529     1330
# 646     1447
# 652     1453
# 653     1454
# 673     1474
# 733     1534
# 791     1592
# 839     1640
# 860     1661
# 1045    1846
# 1062    1863
# Name: AD, dtype: int64

# %% [markdown]
# ## 14. Graph the full-flowering date (DOY) over time

# %%
df['Full-flowering date (DOY)'].plot(x='AD', y = 'Full-flowering date (DOY)')

# %% [markdown]
# ## 15. Smooth out the graph
#
# It's so jagged! You can use `df.rolling` to calculate a rolling average.
#
# The following code calculates a **10-year mean**, using the `AD` column as the anchor. If there aren't 20 samples to work with in a row, it'll accept down to 5. Neat, right?
#
# (We're only looking at the final 5)

# %%
df.rolling(10, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean().tail()
# Out:
# 1210    95.9
# 1211    96.9
# 1212    96.4
# 1213    96.6
# 1214    96.0
# Name: Full-flowering date (DOY), dtype: float64

# %%
df['rolling_date'] = df.rolling(20, on='AD', min_periods=5)['Full-flowering date (DOY)'].mean()

# %%
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# 5      806                        NaN                  NaN          NaN
# 6      807                        NaN                  NaN          NaN
# 7      808                        NaN                  NaN          NaN
# 8      809                        NaN                  NaN          NaN
# 9      810                        NaN                  NaN          NaN
# 10     811                        NaN                  NaN          NaN
# 11     812                       92.0                401.0          1.0
# 12     813                        NaN                  NaN          NaN
# 13     814                        NaN                  NaN          NaN
# 14     815                      105.0                415.0          1.0
# 15     816                        NaN                  NaN          NaN
# 16     817                        NaN                  NaN          NaN
# 17     818                        NaN                  NaN          NaN
# 18     819                        NaN                  NaN          NaN
# 19     820                        NaN                  NaN          NaN
# 20     821                        NaN                  NaN          NaN
# 21     822                        NaN                  NaN          NaN
# 22     823                        NaN                  NaN          NaN
# 23     824                        NaN                  NaN          NaN
# 24     825                        NaN                  NaN          NaN
# 25     826                        NaN                  NaN          NaN
# 26     827                        NaN                  NaN          NaN
# 27     828                        NaN                  NaN          NaN
# 28     829                        NaN                  NaN          NaN
# 29     830                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#                                          Data_type_code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name           ReferenceName  rolling_date
# 0                        NaN                     NaN           NaN
# 1                        NaN                     NaN           NaN
# 2                        NaN                     NaN           NaN
# 3                        NaN                     NaN           NaN
# 4                        NaN                     NaN           NaN
# 5                        NaN                     NaN           NaN
# 6                        NaN                     NaN           NaN
# 7                        NaN                     NaN           NaN
# 8                        NaN                     NaN           NaN
# 9                        NaN                     NaN           NaN
# 10                       NaN                     NaN           NaN
# 11                NIHON-KOKI              NIHON-KOKI           NaN
# 12                       NaN                     NaN           NaN
# 13                       NaN                     NaN           NaN
# 14                NIHON-KOKI              NIHON-KOKI           NaN
# 15                       NaN                     NaN           NaN
# 16                       NaN                     NaN           NaN
# 17                       NaN                     NaN           NaN
# 18                       NaN                     NaN           NaN
# 19                       NaN                     NaN           NaN
# 20                       NaN                     NaN           NaN
# 21                       NaN                     NaN           NaN
# 22                       NaN                     NaN           NaN
# 23                       NaN                     NaN           NaN
# 24                       NaN                     NaN           NaN
# 25                       NaN                     NaN           NaN
# 26                       NaN                     NaN           NaN
# 27                       NaN                     NaN           NaN
# 28                       NaN                     NaN           NaN
# 29                       NaN                     NaN           NaN
# ...                      ...                     ...           ...
# 1185  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.65
# 1186  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.55
# 1187  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.90
# 1188  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.50
# 1189  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.55
# 1190  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.50
# 1191  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.25
# 1192  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.25
# 1193  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.25
# 1194  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.20
# 1195  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.40
# 1196  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.60
# 1197  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.95
# 1198  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.80
# 1199  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.70
# 1200  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.55
# 1201  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.45
# 1202  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.40
# 1203  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.55
# 1204  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.55
# 1205  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35
# 1206  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.45
# 1207  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         95.90
# 1208  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.00
# 1209  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35
# 1210  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.45
# 1211  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.80
# 1212  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.60
# 1213  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35
# 1214  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.05
#
# [1215 rows x 8 columns]

# %%
df.plot(x='AD',y='rolling_date', ylim=(80,120),figsize=(10,10),color = 'pink')

# %% [markdown]
# Use the code above to create a new column called `rolling_date` in our dataset. It should be the 20-year rolling average of the flowering date. Then plot it, with the year on the x axis and the day of the year on the y axis.
#
# Try adding `ylim=(80, 120)` to your `.plot` command to make things look a little less dire.

# %% [markdown]
# ### 16. Add a month column
#
# Right now the "Full-flowering date" column is pretty rough. It uses numbers like '402' to mean "April 2nd" and "416" to mean "April 16th." Let's make a column to explain what month it happened in.
#
# * Every row that happened in April should have 'April' in the `month` column.
# * Every row that happened in March should have 'March' as the `month` column.
# * Every row that happened in May should have 'May' as the `month` column.
#
# **I've given you March as an example**, you just need to add in two more lines to do April and May.

# %%
df.loc[df['Full-flowering date'] < 600, 'month'] = 'May'
df.loc[df['Full-flowering date'] < 500, 'month'] = 'April'
df.loc[df['Full-flowering date'] < 400, 'month'] = 'March'

# %% [markdown]
# ### 17. Using your new column, how many blossomings happened in each month?

# %%
df.month.value_counts()
# Out:
# April    814
# March     10
# May        3
# Name: month, dtype: int64

# %% [markdown]
# ### 18. Graph how many blossomings happened in each month.

# %%
df.month.value_counts().plot(kind='bar',color='pink')

# %% [markdown]
# ## 19. Adding a day-of-month column
#
# Now we're going to add a new column called "day of month." It's actually a little tougher than it should be since the `Full-flowering date` column is a *float* instead of an integer.

# %%
df
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0      801                        NaN                  NaN          NaN
# 1      802                        NaN                  NaN          NaN
# 2      803                        NaN                  NaN          NaN
# 3      804                        NaN                  NaN          NaN
# 4      805                        NaN                  NaN          NaN
# 5      806                        NaN                  NaN          NaN
# 6      807                        NaN                  NaN          NaN
# 7      808                        NaN                  NaN          NaN
# 8      809                        NaN                  NaN          NaN
# 9      810                        NaN                  NaN          NaN
# 10     811                        NaN                  NaN          NaN
# 11     812                       92.0                401.0          1.0
# 12     813                        NaN                  NaN          NaN
# 13     814                        NaN                  NaN          NaN
# 14     815                      105.0                415.0          1.0
# 15     816                        NaN                  NaN          NaN
# 16     817                        NaN                  NaN          NaN
# 17     818                        NaN                  NaN          NaN
# 18     819                        NaN                  NaN          NaN
# 19     820                        NaN                  NaN          NaN
# 20     821                        NaN                  NaN          NaN
# 21     822                        NaN                  NaN          NaN
# 22     823                        NaN                  NaN          NaN
# 23     824                        NaN                  NaN          NaN
# 24     825                        NaN                  NaN          NaN
# 25     826                        NaN                  NaN          NaN
# 26     827                        NaN                  NaN          NaN
# 27     828                        NaN                  NaN          NaN
# 28     829                        NaN                  NaN          NaN
# 29     830                        NaN                  NaN          NaN
# ...    ...                        ...                  ...          ...
# 1185  1986                      102.0                412.0          3.0
# 1186  1987                       95.0                405.0          3.0
# 1187  1988                      106.0                415.0          3.0
# 1188  1989                       93.0                403.0          3.0
# 1189  1990                       88.0                329.0          3.0
# 1190  1991                       97.0                407.0          4.0
# 1191  1992                       94.0                403.0          4.0
# 1192  1993                       97.0                407.0          4.0
# 1193  1994                       99.0                409.0          4.0
# 1194  1995                       99.0                409.0          4.0
# 1195  1996                      103.0                412.0          4.0
# 1196  1997                       97.0                407.0          4.0
# 1197  1998                       91.0                401.0          4.0
# 1198  1999                       94.0                404.0          4.0
# 1199  2000                      100.0                409.0          4.0
# 1200  2001                       96.0                406.0          4.0
# 1201  2002                       91.0                401.0          4.0
# 1202  2003                       98.0                408.0          4.0
# 1203  2004                       92.0                401.0          4.0
# 1204  2005                       99.0                409.0          4.0
# 1205  2006                       98.0                408.0          5.0
# 1206  2007                       97.0                407.0          5.0
# 1207  2008                       95.0                404.0          6.0
# 1208  2009                       95.0                405.0          6.0
# 1209  2010                       95.0                405.0          7.0
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#                                          Data_type_code  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                                                   NaN
# 7                                                   NaN
# 8                                                   NaN
# 9                                                   NaN
# 10                                                  NaN
# 11    from diary description about cherry blossom vi...
# 12                                                  NaN
# 13                                                  NaN
# 14    from diary description about cherry blossom vi...
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                                  NaN
# 19                                                  NaN
# 20                                                  NaN
# 21                                                  NaN
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 1185  data from modern times (full-bloom date since ...
# 1186  data from modern times (full-bloom date since ...
# 1187  data from modern times (full-bloom date since ...
# 1188  data from modern times (full-bloom date since ...
# 1189  data from modern times (full-bloom date since ...
# 1190  data from modern times (full-bloom date since ...
# 1191  data from modern times (full-bloom date since ...
# 1192  data from modern times (full-bloom date since ...
# 1193  data from modern times (full-bloom date since ...
# 1194  data from modern times (full-bloom date since ...
# 1195  data from modern times (full-bloom date since ...
# 1196  data from modern times (full-bloom date since ...
# 1197  data from modern times (full-bloom date since ...
# 1198  data from modern times (full-bloom date since ...
# 1199  data from modern times (full-bloom date since ...
# 1200  data from modern times (full-bloom date since ...
# 1201  data from modern times (full-bloom date since ...
# 1202  data from modern times (full-bloom date since ...
# 1203  data from modern times (full-bloom date since ...
# 1204  data from modern times (full-bloom date since ...
# 1205  data from modern times (full-bloom date since ...
# 1206  data from modern times (full-bloom date since ...
# 1207  data from modern times (full-bloom date since ...
# 1208  data from modern times (full-bloom date since ...
# 1209  data from modern times (full-bloom date since ...
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name           ReferenceName  rolling_date  month
# 0                        NaN                     NaN           NaN    NaN
# 1                        NaN                     NaN           NaN    NaN
# 2                        NaN                     NaN           NaN    NaN
# 3                        NaN                     NaN           NaN    NaN
# 4                        NaN                     NaN           NaN    NaN
# 5                        NaN                     NaN           NaN    NaN
# 6                        NaN                     NaN           NaN    NaN
# 7                        NaN                     NaN           NaN    NaN
# 8                        NaN                     NaN           NaN    NaN
# 9                        NaN                     NaN           NaN    NaN
# 10                       NaN                     NaN           NaN    NaN
# 11                NIHON-KOKI              NIHON-KOKI           NaN  April
# 12                       NaN                     NaN           NaN    NaN
# 13                       NaN                     NaN           NaN    NaN
# 14                NIHON-KOKI              NIHON-KOKI           NaN  April
# 15                       NaN                     NaN           NaN    NaN
# 16                       NaN                     NaN           NaN    NaN
# 17                       NaN                     NaN           NaN    NaN
# 18                       NaN                     NaN           NaN    NaN
# 19                       NaN                     NaN           NaN    NaN
# 20                       NaN                     NaN           NaN    NaN
# 21                       NaN                     NaN           NaN    NaN
# 22                       NaN                     NaN           NaN    NaN
# 23                       NaN                     NaN           NaN    NaN
# 24                       NaN                     NaN           NaN    NaN
# 25                       NaN                     NaN           NaN    NaN
# 26                       NaN                     NaN           NaN    NaN
# 27                       NaN                     NaN           NaN    NaN
# 28                       NaN                     NaN           NaN    NaN
# 29                       NaN                     NaN           NaN    NaN
# ...                      ...                     ...           ...    ...
# 1185  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.65  April
# 1186  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.55  April
# 1187  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.90  April
# 1188  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         99.50  April
# 1189  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.55  March
# 1190  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.50  April
# 1191  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.25  April
# 1192  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.25  April
# 1193  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.25  April
# 1194  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.20  April
# 1195  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.40  April
# 1196  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         98.60  April
# 1197  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.95  April
# 1198  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.80  April
# 1199  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.70  April
# 1200  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.55  April
# 1201  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.45  April
# 1202  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         97.40  April
# 1203  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.55  April
# 1204  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.55  April
# 1205  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35  April
# 1206  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.45  April
# 1207  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         95.90  April
# 1208  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.00  April
# 1209  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35  April
# 1210  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.45  April
# 1211  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.80  April
# 1212  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.60  April
# 1213  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35  April
# 1214  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.05  April
#
# [1215 rows x 9 columns]

# %% [markdown]
# And if you try to convert it to an int, **pandas yells at you!**

# %%
df_flowering['Full-flowering date'].astype(int).
# Out:
#   File "<ipython-input-162-a392e7e5f439>", line 1
#     df_flowering['Full-flowering date'].astype(int).
#                                                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# That's because, as you can read, you can't have an `NaN` be an integer. But, for some reason, it *can* be a float. Ugh! So what we'll do is **drop all of the na values, then convert them to integers to get rid of the decimals.**
#
# I'll show you the first 5 here.

# %%
df['Full-flowering date'].dropna().astype(int).head()
# Out:
# 11    401
# 14    415
# 30    406
# 50    418
# 52    414
# Name: Full-flowering date, dtype: int64

# %% [markdown]
# On the next line, I take the first character of the row and add a bunch of exclamation points on it. I want you to edit this code to **return the last TWO digits of the number**. This only shows you the first 5, by the way.
#
# You might want to look up 'list slicing.'

# %%
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[0] + "!!!").head()
# Out:
# 11    4!!!
# 14    4!!!
# 30    4!!!
# 50    4!!!
# 52    4!!!
# Name: Full-flowering date, dtype: object

# %%
df_flowering['Full-flowering date'] = df_flowering['Full-flowering date'].astype(int)

# %%
df_flowering['Full-flowering date'].astype(str).apply(lambda value: value[-2:])
df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[-2:])
# Out:
# 11      01
# 14      15
# 30      06
# 50      18
# 52      14
# 63      09
# 65      16
# 68      05
# 88      14
# 90      19
# 91      17
# 93      16
# 94      14
# 95      13
# 101     12
# 107     07
# 111     04
# 112     20
# 116     05
# 122     14
# 125     08
# 129     07
# 132     16
# 140     19
# 148     17
# 149     05
# 154     30
# 156     22
# 157     19
# 158     07
#         ..
# 1185    12
# 1186    05
# 1187    15
# 1188    03
# 1189    29
# 1190    07
# 1191    03
# 1192    07
# 1193    09
# 1194    09
# 1195    12
# 1196    07
# 1197    01
# 1198    04
# 1199    09
# 1200    06
# 1201    01
# 1202    08
# 1203    01
# 1204    09
# 1205    08
# 1206    07
# 1207    04
# 1208    05
# 1209    05
# 1210    09
# 1211    10
# 1212    03
# 1213    04
# 1214    03
# Name: Full-flowering date, Length: 827, dtype: object

# %% [markdown]
# Now that you've successfully extracted the last two letters, save them into a new column called `'day-of-month'`

# %%
df['day-of-month'] = df['Full-flowering date'].dropna().astype(int).astype(str).apply(lambda value: value[-2:])

# %%
df.head()
# Out:
#     AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 0  801                        NaN                  NaN          NaN
# 1  802                        NaN                  NaN          NaN
# 2  803                        NaN                  NaN          NaN
# 3  804                        NaN                  NaN          NaN
# 4  805                        NaN                  NaN          NaN
#
#   Data_type_code Reference Name ReferenceName  rolling_date month day-of-month
# 0            NaN            NaN           NaN           NaN   NaN          NaN
# 1            NaN            NaN           NaN           NaN   NaN          NaN
# 2            NaN            NaN           NaN           NaN   NaN          NaN
# 3            NaN            NaN           NaN           NaN   NaN          NaN
# 4            NaN            NaN           NaN           NaN   NaN          NaN

# %% [markdown]
# ### 20. Adding a date column
#
# Now take the `'month'` and `'day-of-month'` columns and combine them in order to create a new column called `'date'`

# %%
df['date'] = df['month'] + " " + df['day-of-month']
df.tail()
# Out:
#         AD  Full-flowering date (DOY)  Full-flowering date  Source code  \
# 1210  2011                       99.0                409.0          8.0
# 1211  2012                      101.0                410.0          8.0
# 1212  2013                       93.0                403.0          8.0
# 1213  2014                       94.0                404.0          8.0
# 1214  2015                       93.0                403.0          8.0
#
#                                          Data_type_code  \
# 1210  data from modern times (full-bloom date since ...
# 1211  data from modern times (full-bloom date since ...
# 1212  data from modern times (full-bloom date since ...
# 1213  data from modern times (full-bloom date since ...
# 1214  data from modern times (full-bloom date since ...
#
#               Reference Name           ReferenceName  rolling_date  month  \
# 1210  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.45  April
# 1211  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.80  April
# 1212  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.60  April
# 1213  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.35  April
# 1214  NEWS-PAPER(ARASHIYAMA)  NEWS-PAPER(ARASHIYAMA)         96.05  April
#
#      day-of-month      date
# 1210           09  April 09
# 1211           10  April 10
# 1212           03  April 03
# 1213           04  April 04
# 1214           03  April 03

# %% [markdown]
# # YOU ARE DONE.
#
# And **incredible.**
